# %%
import pandas as pd
import sys,os,copy,pdb,importlib
sys.path.append('../classes')
sys.path.append('../analysis')
import numpy as np
import matplotlib.pyplot as plt

import tournament_new as tn
import create_database as cd
importlib.reload(tn)

import beck.beck_game
from importlib import reload
reload(beck.beck_game)
from beck.beck_game import BeckGame as Game
game = Game(4,9,4)

from arena import Arena
from mcts import MCTS
importlib.reload(tn)
game = Game(4,9,4)
all_p = pd.read_pickle(cd.DATABASE_LOC)

# res = tn.merge_res_to_base()
tournament_res = pd.read_pickle('/scratch/zz737/fiar/tournaments/ai_all_player_round_robin_base.pkl')

import argparse
import os
import shutil
import time
import random
import numpy as np
import math
import sys

import keras
import keras.backend as K
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import metrics

sys.path.append('..')
from neural_net import NeuralNet
from utils import *

reload(beck.beck_nnet)
from beck.beck_nnet import OthelloNNet, NNetWrapper

import beck.beck_nnet_pvcorr as bnp
reload(bnp)
# Out:
# <module 'beck.beck_nnet_pvcorr' from '../classes/beck/beck_nnet_pvcorr.py'>

# %%
# load and organize data
from pickle import Pickler, Unpickler
weight_dir = '/scratch/zz737/fiar/tournaments/tournament_6/checkpoints_mcts100_cpuct2_id_0'
fn = 'checkpoint_8.pth.tar'
load_folder_file = (weight_dir,fn)

modelFile = os.path.join(load_folder_file[0], load_folder_file[1])
examplesFile = modelFile + ".examples"
with open(examplesFile, "rb") as f:
    trainExamplesHistory = Unpickler(f).load()


from random import shuffle
trainExamples = []
for e in trainExamplesHistory:
    trainExamples.extend(e)
shuffle(trainExamples)
N_trainexs = len(trainExamples)

# input_boards, target_pis, target_vs = list(zip(*trainExamples[:10]))
# input_boards = np.asarray(input_boards)
# target_pis = np.asarray(target_pis)
# target_vs = np.asarray(target_vs)

# %%
# create agent before training:

args = bnp.args
args.batch_size = 50
assert N_trainexs % args.batch_size ==0

pnet = NNetWrapper(game)
pnet.load_checkpoint(folder=weight_dir, filename=fn)

nnet = NNetWrapper(game,args=args)
nnet.load_checkpoint(folder=weight_dir, filename=fn)

reload(bnp)
nnet_pvcorr = bnp.NNetWrapper_pvcorr(game,args=args)
nnet_pvcorr.load_checkpoint(folder=weight_dir, filename=fn)

nnet_dict = {'p':pnet,'n':nnet,'n_pvcorr':nnet_pvcorr}

# %%
# training
for pl, val in nnet_dict.items():
    if pl!='p':
        print(f'player {pl}')
        val.train(trainExamples)
# Out:
# player n
# Epoch 1/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.4271 - pi_loss: 2.1152 - v_loss: 0.3119
# Epoch 2/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3808 - pi_loss: 2.0866 - v_loss: 0.2942
# Epoch 3/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3585 - pi_loss: 2.0717 - v_loss: 0.2867
# Epoch 4/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3434 - pi_loss: 2.0614 - v_loss: 0.2819
# Epoch 5/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3364 - pi_loss: 2.0581 - v_loss: 0.2783
# Epoch 6/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3250 - pi_loss: 2.0501 - v_loss: 0.2749
# Epoch 7/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3235 - pi_loss: 2.0482 - v_loss: 0.2753
# Epoch 8/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3203 - pi_loss: 2.0448 - v_loss: 0.2755
# Epoch 9/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3144 - pi_loss: 2.0417 - v_loss: 0.2727
# Epoch 10/10
# 561/561 [==============================] - 4s 8ms/step - loss: 2.3107 - pi_loss: 2.0388 - v_loss: 0.2720
# player n_pvcorr
# Epoch 1/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.7249 - output_1_loss: 2.1409 - output_2_loss: 0.3369 - output_3_loss: 0.2470
# Epoch 2/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.5666 - output_1_loss: 2.1189 - output_2_loss: 0.3140 - output_3_loss: 0.1336
# Epoch 3/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.5073 - output_1_loss: 2.1099 - output_2_loss: 0.2992 - output_3_loss: 0.0982
# Epoch 4/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.4734 - output_1_loss: 2.0975 - output_2_loss: 0.2928 - output_3_loss: 0.0831
# Epoch 5/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.4529 - output_1_loss: 2.0895 - output_2_loss: 0.2892 - output_3_loss: 0.0743
# Epoch 6/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.4360 - output_1_loss: 2.0833 - output_2_loss: 0.2853 - output_3_loss: 0.0674
# Epoch 7/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.4197 - output_1_loss: 2.0739 - output_2_loss: 0.2824 - output_3_loss: 0.0634
# Epoch 8/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.4072 - output_1_loss: 2.0708 - output_2_loss: 0.2790 - output_3_loss: 0.0574
# Epoch 9/10
# 718/718 [==============================] - 72s 101ms/step - loss: 2.3979 - output_1_loss: 2.0648 - output_2_loss: 0.2785 - output_3_loss: 0.0546
# Epoch 10/10
# 718/718 [==============================] - 72s 100ms/step - loss: 2.3884 - output_1_loss: 2.0624 - output_2_loss: 0.2762 - output_3_loss: 0.0498

# %%
# create mcts and agents 
n_mcts = 100
cpuct = 2
tree_args = dotdict({
'numMCTSSims': n_mcts,
'cpuct': cpuct,
})
tree_dict = {}
ai_dict = {}
for player,val_func in nnet_dict.items():
    tree_dict[player] = MCTS(game,val_func,tree_args)
    ai_dict[player] = lambda x: np.random.choice(np.arange(game.getActionSize()),p=tree_dict[player].getActionProb(x, temp=1/10))

# %%
participants = [['p','n'],['p','n_pvcorr'],['n','n_pvcorr']]
res_l = []
ngames = 10
for p1,p2 in participants:
    print(f'{p1} vs {p2}')
    arena = Arena(ai_dict[p1],ai_dict[p2],game,display=game.display,tree1=tree_dict[p1],tree2=tree_dict[p2])
    res=arena.playGames(ngames,verbose=True)
    res_l.append(res)
    print(f'{p1} vs {p2}')
    print(f'result {res}')
    
for p1,p2 in participants:
    print(f'{p1} vs {p2}')
    print(f'result {res}')
# Out:
# Arena.playGames (1):   0%|          | 0/5 [00:00<?, ?it/s]
# p vs n
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O - - - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O - - - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O - O - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Arena.playGames (1):  20%|██        | 1/5 [00:22<01:30, 22.61s/it]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - - - - - |
# 1 |- - - O - X - O - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X X - - - - |
# 1 |- - - O - X - O - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X X - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X X - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - O O - - - - |
# 2 |- - - O X X - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X - - - |
# 3 |- - O - - O - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X - - - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X O - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X - - - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X O - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X X - - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X O - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X X O - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X O - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X X O - |
# 3 |- - O X - O - X - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- - - O O X - - - |
# 2 |- - - O X X X O - |
# 3 |- - O X - O - X - |
# -----------------------
# Turn  17 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- - - O O X - - - |
# 2 |- - X O X X X O - |
# 3 |- - O X - O - X - |
# -----------------------
# Turn  18 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- O - O O X - - - |
# 2 |- - X O X X X O - |
# 3 |- - O X - O - X - |
# -----------------------
# Turn  19 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- O X O O X - - - |
# 2 |- - X O X X X O - |
# 3 |- - O X - O - X - |
# -----------------------
# Turn  20 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- O X O O X - - - |
# 2 |- - X O X X X O - |
# 3 |- - O X - O O X - |
# -----------------------
# Turn  21 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- O X O O X X - - |
# 2 |- - X O X X X O - |
# 3 |- - O X - O O X - |
# -----------------------
# Turn  22 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - O X O - - |
# 1 |- O X O O X X - - |
# 2 |- - X O X X X O - |
# 3 |- - O X O O O X - |
# -----------------------
# Turn  23 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - - O X O - - |
# 1 |- O X O O X X - - |
# 2 |- - X O X X X O - |
# 3 |- - O X O O O X - |
# -----------------------
# Turn  24 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - O O X O - - |
# 1 |- O X O O X X - - |
# 2 |- - X O X X X O - |
# 3 |- - O X O O O X - |
# -----------------------
# Turn  25 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - O O X O - - |
# 1 |- O X O O X X - X |
# 2 |- - X O X X X O - |
# 3 |- - O X O O O X - |
# -----------------------
# Turn  26 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - O O X O - - |
# 1 |- O X O O X X O X |
# 2 |- - X O X X X O - |
# 3 |- - O X O O O X - |
# -----------------------
# Turn  27 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O - - |
# 1 |- O X O O X X O X |
# 2 |- - X O X X X O - |
# 3 |- - O X O O O X - |
# -----------------------
# Turn  28 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O - - |
# 1 |- O X O O X X O X |
# 2 |- - X O X X X O - |
# 3 |- O O X O O O X - |
# -----------------------
# Turn  29 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O X - |
# 1 |- O X O O X X O X |
# 2 |- - X O X X X O - |
# 3 |- O O X O O O X - |
# -----------------------
# Turn  30 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O X O |
# 1 |- O X O O X X O X |
# 2 |- - X O X X X O - |
# 3 |- O O X O O O X - |
# -----------------------
# Turn  31 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O X O |
# 1 |- O X O O X X O X |
# 2 |- - X O X X X O - |
# 3 |X O O X O O O X - |
# -----------------------
# Turn  32 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O X O |
# 1 |- O X O O X X O X |
# 2 |- O X O X X X O - |
# 3 |X O O X O O O X - |
# -----------------------
# Arena.playGames (1):  40%|████      | 2/5 [01:12<01:32, 30.89s/it]
# Turn  33 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X O O X O X O |
# 1 |- O X O O X X O X |
# 2 |X O X O X X X O - |
# 3 |X O O X O O O X - |
# -----------------------
# Turn  34 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X X O O X O X O |
# 1 |- O X O O X X O X |
# 2 |X O X O X X X O - |
# 3 |X O O X O O O X - |
# -----------------------
# Turn  35 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X X O O X O X O |
# 1 |X O X O O X X O X |
# 2 |X O X O X X X O - |
# 3 |X O O X O O O X - |
# -----------------------
# Turn  36 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X X O O X O X O |
# 1 |X O X O O X X O X |
# 2 |X O X O X X X O - |
# 3 |X O O X O O O X O |
# -----------------------
# Game over: Turn  36 Result  0.0001
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X X O O X O X O |
# 1 |X O X O O X X O X |
# 2 |X O X O X X X O X |
# 3 |X O O X O O O X O |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O O - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O O X - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - O O O X - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - X O O O X - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - X O O O X - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - X O O O X - - |
# 2 |- - - O X - - - - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - X O O O X - - |
# 2 |- - - O X - - - - |
# 3 |- - - X - - O - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X - - O - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X - O O - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - X - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X - O O - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - X - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X O O O - - |
# -----------------------
# Turn  17 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - X - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X O O O X - |
# -----------------------
# Turn  18 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O - X - X - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X O O O X - |
# -----------------------
# Turn  19 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O - X X X - |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X O O O X - |
# -----------------------
# Arena.playGames (1):  60%|██████    | 3/5 [01:42<01:01, 30.66s/it]
# Turn  20 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O - X X X O |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X O O O X - |
# -----------------------
# Game over: Turn  20 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O X X X X O |
# 1 |- - X O O O X - - |
# 2 |- - - O X X - - - |
# 3 |- - - X O O O X - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O O - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Arena.playGames (1):  80%|████████  | 4/5 [01:53<00:24, 24.56s/it]
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - - - |
# 1 |- - - - O O - - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - - - |
# 1 |- - - - O O O - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - - - |
# 1 |- - - X O O O - - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Game over: Turn  9 Result  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - - - |
# 1 |- - - X O O O O - |
# 2 |- - - O X - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - X - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - X - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - X - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O - - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O - - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - O - - |
# 1 |- - X O O O X - - |
# 2 |- - X O - - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - O - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - O O - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Turn  17 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - O O - - |
# 1 |- - X O O O X - - |
# 2 |- X X O X - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Arena.playGames (1): 100%|██████████| 5/5 [02:21<00:00, 28.26s/it]
# Arena.playGames (2):   0%|          | 0/5 [00:00<?, ?it/s]
# Turn  18 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O O X - O O - - |
# 1 |- - X O O O X - - |
# 2 |- X X O X - - - - |
# 3 |- - X O - X - - - |
# -----------------------
# Game over: Turn  18 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O O X - O O - - |
# 1 |- - X O O O X - - |
# 2 |- X X O X - - - - |
# 3 |X - X O - X - - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- X X - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O - - - |
# 2 |- - X O - - - - - |
# 3 |- X X - - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O - - - - - |
# 3 |- X X - - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O - - - - - |
# 3 |- X X - - O - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- X X - - O - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- X X - - O O - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- X X X - O O - - |
# -----------------------
# Arena.playGames (2):  20%|██        | 1/5 [00:23<01:33, 23.38s/it]
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- X X X - O O - O |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O O X - - |
# 2 |- - X O X - - - - |
# 3 |- X X X X O O - O |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - X - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X O X - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X O X - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X - X - |
# -----------------------
# Arena.playGames (2):  40%|████      | 2/5 [00:41<01:05, 21.89s/it]
# Game over: Turn  15 Result  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O O - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X - X - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X - X - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O - - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X O X - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - X O X - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O - - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X - - - |
# -----------------------
# Arena.playGames (2):  60%|██████    | 3/5 [00:55<00:38, 19.28s/it]
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O - - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X X - - |
# -----------------------
# Game over: Turn  15 Result  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O X - - - - - |
# 1 |- - X O O O O - - |
# 2 |- - X O O - - - - |
# 3 |- - X O X X X - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - X - |
# 1 |- - - O O - - - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - X - |
# 1 |- - - O O - O - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - X - |
# 1 |- - - O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - X - |
# 1 |- - - O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - X - |
# 1 |- - - O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - X - |
# 1 |- O - O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - X - |
# 1 |- O X O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X - X - |
# 1 |- O X O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Arena.playGames (2):  80%|████████  | 4/5 [01:17<00:20, 20.15s/it]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - X X X - |
# 1 |- O X O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X O X X X - |
# 1 |- O X O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X O X X X X |
# 1 |- O X O O X O - - |
# 2 |- - X O - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O X X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - O X X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - O X X - - - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - O - O - - - |
# 2 |- - - O X X - - - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - O - O - - - |
# 2 |- - - O X X X - - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - O - O - - - |
# 2 |- - - O X X X O - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - - - - - |
# 1 |- - - O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O - - - - - |
# 1 |- - - O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O X - - - - |
# 1 |- - - O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - - X - - - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O X - - - - |
# 1 |- - - O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - - X O - - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O X - - - - |
# 1 |- - - O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - X X O - - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - O O X - - - - |
# 1 |- - O O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - X X O - - - - |
# -----------------------
# Turn  17 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |- - O O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - X X O - - - - |
# -----------------------
# Turn  18 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |- O O O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - X X O - - - - |
# -----------------------
# Turn  19 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O - - - |
# 2 |- - - O X X X O - |
# 3 |- - X X O - - - - |
# -----------------------
# Turn  20 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O - - |
# 2 |- - - O X X X O - |
# 3 |- - X X O - - - - |
# -----------------------
# Turn  21 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O - - |
# 2 |- - - O X X X O - |
# 3 |- X X X O - - - - |
# -----------------------
# Turn  22 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O - - |
# 2 |- - - O X X X O - |
# 3 |O X X X O - - - - |
# -----------------------
# Turn  23 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O - - |
# 2 |- X - O X X X O - |
# 3 |O X X X O - - - - |
# -----------------------
# Turn  24 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O O - |
# 2 |- X - O X X X O - |
# 3 |O X X X O - - - - |
# -----------------------
# Turn  25 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O - - - - |
# -----------------------
# Turn  26 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - - - |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O - - O - |
# -----------------------
# Turn  27 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - X - |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O - - O - |
# -----------------------
# Turn  28 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - X - |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O - O O - |
# -----------------------
# Turn  29 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - X - |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O X O O - |
# -----------------------
# Arena.playGames (2): 100%|██████████| 5/5 [02:00<00:00, 24.18s/it]
# Arena.playGames (1):   0%|          | 0/5 [00:00<?, ?it/s]
# Turn  30 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - - X O |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O X O O - |
# -----------------------
# Turn  31 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X - X X O |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O X O O - |
# -----------------------
# Turn  32 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X O X X O |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O X O O - |
# -----------------------
# Turn  33 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X O O X O X X O |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O X O O X |
# -----------------------
# Turn  34 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X O O X O X X O |
# 1 |X O O O X O O O X |
# 2 |- X - O X X X O - |
# 3 |O X X X O X O O X |
# -----------------------
# Turn  35 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X O O X O X X O |
# 1 |X O O O X O O O X |
# 2 |- X X O X X X O - |
# 3 |O X X X O X O O X |
# -----------------------
# Turn  36 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X O O X O X X O |
# 1 |X O O O X O O O X |
# 2 |O X X O X X X O - |
# 3 |O X X X O X O O X |
# -----------------------
# Game over: Turn  36 Result  0.0001
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O X O O X O X X O |
# 1 |X O O O X O O O X |
# 2 |O X X O X X X O X |
# 3 |O X X X O X O O X |
# -----------------------
# p vs n
# result (3, 5, 2)
# p vs n_pvcorr
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - O - X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O - X - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O - X X - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O - X X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O - X X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O - - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - O - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - X X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - O - - - |
# -----------------------
# Arena.playGames (1):  20%|██        | 1/5 [00:17<01:09, 17.29s/it]
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - X X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - O - O - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X X X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - O - O - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X X X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - O O O - |
# -----------------------
# Game over: Turn  14 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X X X - - - |
# 1 |- - - - O X - - - |
# 2 |- - - O O X X - - |
# 3 |- - O - - O O O - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O - - - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O - - - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O - O - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O - - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O - - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O - |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X - X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Arena.playGames (1):  40%|████      | 2/5 [00:40<00:56, 18.94s/it]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - O O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X X - - - - |
# 1 |- - - O - X - - - |
# 2 |- - O O X O O O X |
# 3 |- - - O - X - O - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - O - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - X O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - X O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - - X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - - X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - X X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X - O - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X X O - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O - O - X - - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X X O - - - |
# -----------------------
# Turn  17 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O - O - X X - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X X O - - - |
# -----------------------
# Turn  18 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O - O - X X - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O O - - |
# 3 |- - O X X O - - - |
# -----------------------
# Turn  19 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O - O - X X - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O O X - |
# 3 |- - O X X O - - - |
# -----------------------
# Turn  20 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O O O - X X - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O O X - |
# 3 |- - O X X O - - - |
# -----------------------
# Arena.playGames (1):  60%|██████    | 3/5 [01:06<00:42, 21.12s/it]
# Turn  21 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- O O O X X X - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O O X - |
# 3 |- - O X X O - - - |
# -----------------------
# Game over: Turn  21 Result  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O O O O X X X - - |
# 1 |- O X X X O - - - |
# 2 |- - - X O O O X - |
# 3 |- - O X X O - - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - O - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - - - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - - O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - - O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - X O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - - X - O - - - |
# 2 |- - - X O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - - X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - O - X - - - |
# 1 |- - - X X O - - - |
# 2 |- - - X O O - - - |
# 3 |- - O X - O - - - |
# -----------------------

# %%
tosavefolder = '/scratch/zz737/fiar/tournaments/temp_test'
filename=f'{p}.pth.tar'
