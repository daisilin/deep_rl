# %%
import pandas as pd
import sys,os,copy,pdb,importlib
sys.path.append('../classes')
sys.path.append('../analysis')
import numpy as np
import matplotlib.pyplot as plt

import tournament_new as tn
import create_database as cd
importlib.reload(tn)

import beck.beck_game
from importlib import reload
reload(beck.beck_game)
from beck.beck_game import BeckGame as Game
game = Game(4,9,4)

from arena import Arena
from mcts import MCTS
importlib.reload(tn)
game = Game(4,9,4)
all_p = pd.read_pickle(cd.DATABASE_LOC)

# res = tn.merge_res_to_base()
tournament_res = pd.read_pickle('/scratch/zz737/fiar/tournaments/ai_all_player_round_robin_base.pkl')

import argparse
import os
import shutil
import time
import random
import numpy as np
import math
import sys

import keras
import keras.backend as K
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import metrics

sys.path.append('..')
from neural_net import NeuralNet
from utils import *

reload(beck.beck_nnet)
from beck.beck_nnet import OthelloNNet, NNetWrapper

import beck.beck_nnet_pvcorr as bnp
reload(bnp)
# Out:
# <module 'beck.beck_nnet_pvcorr' from '../classes/beck/beck_nnet_pvcorr.py'>

# %%
# load and organize data
from pickle import Pickler, Unpickler
weight_dir = '/scratch/zz737/fiar/tournaments/tournament_6/checkpoints_mcts100_cpuct2_id_0'
fn = 'checkpoint_8.pth.tar'
load_folder_file = (weight_dir,fn)

modelFile = os.path.join(load_folder_file[0], load_folder_file[1])
examplesFile = modelFile + ".examples"
with open(examplesFile, "rb") as f:
    trainExamplesHistory = Unpickler(f).load()


from random import shuffle
trainExamples = []
for e in trainExamplesHistory:
    trainExamples.extend(e)
shuffle(trainExamples)

# input_boards, target_pis, target_vs = list(zip(*trainExamples[:10]))
# input_boards = np.asarray(input_boards)
# target_pis = np.asarray(target_pis)
# target_vs = np.asarray(target_vs)

# %%
# create agent before training:

args = bnp.args
args.batch_size = 10

pnet = NNetWrapper(game)
pnet.load_checkpoint(folder=weight_dir, filename=fn)

nnet = NNetWrapper(game,args=args)
nnet.load_checkpoint(folder=weight_dir, filename=fn)

reload(bnp)
nnet_pvcorr = bnp.NNetWrapper_pvcorr(game,args=args)
nnet_pvcorr.load_checkpoint(folder=weight_dir, filename=fn)

nnet_dict = {'p':pnet,'n':nnet,'n_pvcorr':nnet_pvcorr}

# %%
# training
for pl, val in nnet_dict.items():
    if pl!='p':
        print(f'player {pl}')
        val.train(trainExamples[:10])
# Out:
# player n
# Epoch 1/10
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4443 - pi_loss: 1.7919 - v_loss: 0.6524
# Epoch 2/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7096 - pi_loss: 1.6609 - v_loss: 0.0487
# Epoch 3/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7025 - pi_loss: 1.6596 - v_loss: 0.0429
# Epoch 4/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7110 - pi_loss: 1.6904 - v_loss: 0.0206
# Epoch 5/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6351 - pi_loss: 1.6109 - v_loss: 0.0242
# Epoch 6/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5997 - pi_loss: 1.5681 - v_loss: 0.0316
# Epoch 7/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6051 - pi_loss: 1.5744 - v_loss: 0.0307
# Epoch 8/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5765 - pi_loss: 1.5575 - v_loss: 0.0190
# Epoch 9/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5251 - pi_loss: 1.5118 - v_loss: 0.0132
# Epoch 10/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5059 - pi_loss: 1.4908 - v_loss: 0.0151
# player n_pvcorr
# Epoch 1/10
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7724 - output_1_loss: 1.8254 - output_2_loss: 0.1954 - output_3_loss: 0.7516
# Epoch 2/10
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2619 - output_1_loss: 1.7445 - output_2_loss: 0.0363 - output_3_loss: 0.4811
# Epoch 3/10
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0706 - output_1_loss: 1.6693 - output_2_loss: 0.0309 - output_3_loss: 0.3704
# Epoch 4/10
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1120 - output_1_loss: 1.6855 - output_2_loss: 0.0219 - output_3_loss: 0.4046
# Epoch 5/10
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0338 - output_1_loss: 1.6649 - output_2_loss: 0.0171 - output_3_loss: 0.3518
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9881 - output_1_loss: 1.5745 - output_2_loss: 0.0249 - output_3_loss: 0.3887
# Epoch 7/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9304 - output_1_loss: 1.5907 - output_2_loss: 0.0141 - output_3_loss: 0.3256
# Epoch 8/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9639 - output_1_loss: 1.6280 - output_2_loss: 0.0282 - output_3_loss: 0.3077
# Epoch 9/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8748 - output_1_loss: 1.6065 - output_2_loss: 0.0152 - output_3_loss: 0.2532
# Epoch 10/10
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8547 - output_1_loss: 1.5722 - output_2_loss: 0.0219 - output_3_loss: 0.2607

# %%
# create mcts and agents 
n_mcts = 100
cpuct = 2
tree_args = dotdict({
'numMCTSSims': n_mcts,
'cpuct': cpuct,
})
tree_dict = {}
ai_dict = {}
for player,val_func in nnet_dict.items():
    tree_dict[player] = MCTS(game,val_func,tree_args)
    ai_dict[player] = lambda x: np.random.choice(np.arange(game.getActionSize()),p=tree_dict[player].getActionProb(x, temp=1/10))

# %%
participants = [['p','n'],['p','n_pvcorr'],['n','n_pvcorr']]
res_l = []
ngames = 2
for p1,p2 in participants:
    print(f'{p1} vs {p2}')
    arena = Arena(ai_dict[p1],ai_dict[p2],game,display=game.display,tree1=tree_dict[p1],tree2=tree_dict[p2])
    res=arena.playGames(ngames,verbose=True)
    res_l.append(res)
    print(f'{p1} vs {p2}')
    print(f'result {res}')
    
for p1,p2 in participants:
    print(f'{p1} vs {p2}')
    print(f'result {res}')
# Out:
# Arena.playGames (1):   0%|          | 0/1 [00:00<?, ?it/s]
# p vs n
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O O X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - O - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - - - O - - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - - - O - - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - - - O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - X - O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O - X - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - X - O O - - - |
# 3 |- - - X - O - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O - X - - - - - - |
# 1 |- X - O O X - - - |
# 2 |- - X - O O - - - |
# 3 |- - X X - O - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O - X - - - - - - |
# 1 |- X O O O X - - - |
# 2 |- - X - O O - - - |
# 3 |- - X X - O - - - |
# -----------------------
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O - X - - - - - - |
# 1 |- X O O O X - - - |
# 2 |- - X - O O - - - |
# 3 |- X X X - O - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O - X - - - - - - |
# 1 |- X O O O X - - - |
# 2 |- - X - O O - - - |
# 3 |- X X X O O - - - |
# -----------------------
# Arena.playGames (1): 100%|██████████| 1/1 [00:28<00:00, 28.28s/it]
# Arena.playGames (2):   0%|          | 0/1 [00:00<?, ?it/s]
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |O - X - - - - - - |
# 1 |- X O O O X - - - |
# 2 |- - X - O O - - - |
# 3 |X X X X O O - - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Arena.playGames (2): 100%|██████████| 1/1 [00:27<00:00, 27.32s/it]
# Arena.playGames (1):   0%|          | 0/1 [00:00<?, ?it/s]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |X X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# result (1, 1, 0)
# p vs n_pvcorr
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X - - - |
# 2 |- - - - - - - - - |
# 3 |- - - O - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X - - - |
# 2 |- - - - - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X X - - |
# 2 |- - - - - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X X O - |
# 2 |- - - - - - - - - |
# 3 |- - O O - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X X O - |
# 2 |- - - - - - - - - |
# 3 |- - O O - - X - - |
# -----------------------
# Arena.playGames (1): 100%|██████████| 1/1 [00:21<00:00, 21.51s/it]
# Arena.playGames (2):   0%|          | 0/1 [00:00<?, ?it/s]
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X X O - |
# 2 |- - - - - - - - - |
# 3 |- - O O O - X - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X X O - |
# 2 |- - - - - - - - - |
# 3 |- - O O O - X X - |
# -----------------------
# Game over: Turn  11 Result  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O X X X O - |
# 2 |- - - - - - - - - |
# 3 |- - O O O O X X - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Arena.playGames (2): 100%|██████████| 1/1 [00:25<00:00, 25.71s/it]
# Arena.playGames (1):   0%|          | 0/1 [00:00<?, ?it/s]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |X X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# result (2, 0, 0)
# n vs n_pvcorr
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Arena.playGames (1): 100%|██████████| 1/1 [00:25<00:00, 25.55s/it]
# Arena.playGames (2):   0%|          | 0/1 [00:00<?, ?it/s]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |X X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  1 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - - - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  2 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - - O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  3 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - - - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  4 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - - - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  5 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - - O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  6 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - - O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  7 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - - - - - - - - |
# -----------------------
# Turn  8 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X - - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  9 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O - - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  10 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O - - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  11 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - - - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  12 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O - - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  13 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O - - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  14 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- - X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Arena.playGames (2): 100%|██████████| 1/1 [00:27<00:00, 27.49s/it]
# Turn  15 Player  1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X - O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Turn  16 Player  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |- X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# Game over: Turn  16 Result  -1
#    0 1 2 3 4 5 6 7 8
# -----------------------
# 0 |X X X X O O O - - |
# 1 |- - X O X - - - - |
# 2 |- - X O O O X - - |
# 3 |- - O - - - - - - |
# -----------------------
# result (1, 1, 0)
